# %%
import numpy as np
import matplotlib.pyplot as plt
import mkl

mkl.set_num_threads(4)
np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]
    
    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,  
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = (examples[r, c] - ex_min) / (ex_max - ex_min)
    
    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

# %% [markdown]
# # MNIST dataset

# %%
import mnist
digits = np.reshape(mnist.train_images()[:12*24], newshape=(12, 24, 28, 28))
tiles(digits)

# %% [markdown]
# # Restricted Boltzmann Machine & Contrastive Divergence algorithm

# %%
def sigmoid(matrix):
    return 1.0 / (1.0 + np.exp(-matrix))

class Rbm:
    def __init__(self, visible_size, hidden_size, learning_rate, momentum):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size+1)).astype(np.float32)
        self.W[:, -1] = 0.0
        self.W[-1, :] = 0.0
        self.M = zeros(self.visible_size+1, self.hidden_size+1)

# %%
def reconstuction_error(rbm, minibatch):
    observations_count = minibatch.shape[0]
    visible = zeros(observations_count, rbm.visible_size)
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    hidden[:, :-1] = (sigmoid(minibatch @ rbm.W[:, :-1]) > rand(observations_count, rbm.hidden_size)).astype(np.float32)
    visible = sigmoid(hidden @ rbm.W.T[:, :-1])
    
    error = np.sum(np.power(visible - minibatch[:, :-1], 2))/observations_count

    return error

# %%
def train_epoch(rbm, dataset, batch_size):
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(rbm, batch)
        if batch_idx % round(batches_limit / 50) == 0: print("#", end="")

def run_training(rbm, dataset, monitoring_set, batch_size, epochs_count):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch),  end="\t")
        
        if epoch == 5:
            rbm.momentum = 0.8

        start_time = time.time()
        train_epoch(rbm, dataset, batch_size)
        elapsed = time.time() - start_time
        
        error = reconstuction_error(rbm, monitoring_set)
        print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))

    print("Training finished!")

# %%
def draw_filters(rbm):
    filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
    tiles(filters)

# %% [markdown]
# # 1. RBM Training with momentum

# %%
def cdk(rbm, minibatch, k=1):
    observations_count = minibatch.shape[0]
    
    positive_visible = minibatch
    negative_visible = append_ones(zeros(observations_count, rbm.visible_size))

    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    positive_hidden[:, :-1] = sigmoid(positive_visible @ rbm.W[:, :-1])
    positive_gradient = (positive_visible.T @ positive_hidden) / observations_count
    
    negative_hidden[:, :-1] = (positive_hidden[:, :-1] > rand(observations_count, rbm.hidden_size)).astype(np.float32)
    for i in range(k):
        negative_visible[:, :-1] = (sigmoid(negative_hidden @ rbm.W.T[:, :-1]) > rand(observations_count, rbm.visible_size)).astype(np.float32)
        if i == k-1:
            negative_hidden[:, :-1] = sigmoid(negative_visible @ rbm.W[:, :-1])
        else:
            negative_hidden[:, :-1] = (sigmoid(negative_visible @ rbm.W[:, :-1]) > rand(observations_count, rbm.hidden_size)).astype(np.float32)

    negative_gradient = (negative_visible.T @ negative_hidden) / observations_count
    rbm.M = (rbm.momentum * rbm.M) + rbm.learning_rate*(positive_gradient - negative_gradient)
    rbm.W = rbm.W + rbm.M

# %%
import time

DATASET_SIZE = 20000 # 60000 for whole dataset
DIGIT_SIZE = 28

VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 128

mnist_train = mnist.train_images().astype(np.float32) / 255.0
np.random.shuffle(mnist_train)
dataset = np.reshape(mnist_train[:DATASET_SIZE], newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
dataset = append_ones(dataset)

monitoring_indeces = np.random.choice(DATASET_SIZE, 256, replace=False)
monitoring_set = dataset[monitoring_indeces]

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

LEARNING_RATE = 0.1
MOMENTUM = 0.5

rbm = Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM)
draw_filters(rbm)

run_training(rbm, dataset, monitoring_set, BATCH_SIZE, EPOCHS_COUNT)

draw_filters(rbm)
# Out:
# Epoch 0:	#####################################################	elapsed: 1.46s, reconstruction error: 26.50
# Epoch 1:	#####################################################	elapsed: 1.04s, reconstruction error: 21.39
# Epoch 2:	#####################################################	elapsed: 1.50s, reconstruction error: 18.78
# Epoch 3:	#####################################################	elapsed: 1.36s, reconstruction error: 17.27
# Epoch 4:	#####################################################	elapsed: 1.75s, reconstruction error: 16.32
# Epoch 5:	#####################################################	elapsed: 1.13s, reconstruction error: 15.00
# Epoch 6:	#####################################################	elapsed: 1.36s, reconstruction error: 13.98
# Epoch 7:	#####################################################	elapsed: 1.37s, reconstruction error: 13.31
# Epoch 8:	#####################################################	elapsed: 1.41s, reconstruction error: 12.85
# Epoch 9:	#####################################################	elapsed: 1.27s, reconstruction error: 12.56
# Epoch 10:	#####################################################	elapsed: 1.10s, reconstruction error: 12.17
# Epoch 11:	#####################################################	elapsed: 1.01s, reconstruction error: 11.97
# Epoch 12:	#####################################################	elapsed: 1.01s, reconstruction error: 11.70
# Epoch 13:	#####################################################	elapsed: 1.04s, reconstruction error: 11.70
# Epoch 14:	#####################################################	elapsed: 1.01s, reconstruction error: 11.67
# Epoch 15:	#####################################################	elapsed: 1.02s, reconstruction error: 11.23
# Epoch 16:	#####################################################	elapsed: 1.04s, reconstruction error: 11.33
# Epoch 17:	#####################################################	elapsed: 1.10s, reconstruction error: 11.20
# Epoch 18:	#####################################################	elapsed: 1.04s, reconstruction error: 11.24
# Epoch 19:	#####################################################	elapsed: 1.07s, reconstruction error: 11.04
# Epoch 20:	#####################################################	elapsed: 1.02s, reconstruction error: 10.95
# Epoch 21:	#####################################################	elapsed: 1.04s, reconstruction error: 11.01
# Epoch 22:	#####################################################	elapsed: 1.02s, reconstruction error: 10.73
# Epoch 23:	#####################################################	elapsed: 1.03s, reconstruction error: 10.94
# Epoch 24:	#####################################################	elapsed: 0.99s, reconstruction error: 10.88
# Epoch 25:	#####################################################	elapsed: 1.03s, reconstruction error: 10.82
# Epoch 26:	#####################################################	elapsed: 1.03s, reconstruction error: 10.69
# Epoch 27:	#####################################################	elapsed: 1.08s, reconstruction error: 10.69
# Epoch 28:	#####################################################	elapsed: 1.08s, reconstruction error: 10.63
# Epoch 29:	#####################################################	elapsed: 1.06s, reconstruction error: 10.70
# Epoch 30:	#####################################################	elapsed: 1.07s, reconstruction error: 10.67
# Epoch 31:	#####################################################	elapsed: 1.02s, reconstruction error: 10.49
# Epoch 32:	#####################################################	elapsed: 1.06s, reconstruction error: 10.39
# Epoch 33:	################################################
# /home/andrzej/anaconda3/envs/ed/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in exp
# #####	elapsed: 1.14s, reconstruction error: 10.37
# Epoch 34:	#####################################################	elapsed: 1.13s, reconstruction error: 10.58
# Epoch 35:	#####################################################	elapsed: 1.01s, reconstruction error: 10.35
# Epoch 36:	#####################################################	elapsed: 1.02s, reconstruction error: 10.39
# Epoch 37:	#####################################################	elapsed: 1.05s, reconstruction error: 10.44
# Epoch 38:	#####################################################	elapsed: 1.10s, reconstruction error: 10.42
# Epoch 39:	#####################################################	elapsed: 1.03s, reconstruction error: 10.19
# Epoch 40:	#####################################################	elapsed: 1.03s, reconstruction error: 10.48
# Epoch 41:	#####################################################	elapsed: 1.02s, reconstruction error: 10.35
# Epoch 42:	#####################################################	elapsed: 1.04s, reconstruction error: 10.33
# Epoch 43:	#####################################################	elapsed: 1.01s, reconstruction error: 10.27
# Epoch 44:	#####################################################	elapsed: 1.03s, reconstruction error: 10.21
# Epoch 45:	#####################################################	elapsed: 1.06s, reconstruction error: 10.34
# Epoch 46:	#####################################################	elapsed: 1.03s, reconstruction error: 10.14
# Epoch 47:	#####################################################	elapsed: 1.01s, reconstruction error: 10.27
# Epoch 48:	#####################################################	elapsed: 1.19s, reconstruction error: 10.19
# Epoch 49:	#####################################################	elapsed: 1.05s, reconstruction error: 10.06
# Training finished!

# %% [markdown]
# # 2. DBN Training

# %%
def propagate_up(dbn, layers_count, visible):
    for i in range(layers_count):
        visible = append_ones(sigmoid(visible @ dbn[i].W[:, :-1]))
    return visible

def propagate_down(dbn, layers_count, hidden):
    for i in reversed(range(layers_count)):
        hidden = append_ones(sigmoid(hidden @ np.transpose(dbn[i].W[:-1, :])))
    return hidden

# %% [markdown]
# ### DBN reconstruction error

# %%
def dbn_reconstuction_error(dbn, layers_count, minibatch):
    visible = propagate_up(dbn, layers_count, minibatch)
    error = reconstuction_error(dbn[layers_count], visible)
    
    return error

# %% [markdown]
# ### Sampling in Deep Belief Networks

# %%
def sample_rbm(rbm, minibatch, steps):
    observations_count = minibatch.shape[0]

    visible = minibatch
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    for cd_i in range(steps):
        hidden[:, :-1] = sigmoid(visible @ rbm.W[:, :-1])
        hidden[:, :-1] = (hidden[:, :-1] > rand(observations_count, rbm.hidden_size)).astype(np.float32)
    
        visible[:, :-1] = sigmoid(hidden @ np.transpose(rbm.W[:-1, :]))
        if cd_i < (steps - 1):
            visible[:, :-1] = (visible[:, :-1] > rand(observations_count, rbm.visible_size)).astype(np.float32)

    return visible

# %%
def sample_dbn(dbn, layer_idx, minibatch, steps):
    visible = propagate_up(dbn, layer_idx, minibatch)
    vivible = sample_rbm(dbn[layer_idx], visible, steps)
    visible = propagate_down(dbn, layer_idx, visible)
    return visible

# %%
def draw_layer_samples(dbn, layer_idx, minibatch, steps=200):
    samples = sample_dbn(dbn, layer_idx, minibatch, steps)
    tiles(np.reshape(samples[:, :-1], newshape=(-1, 16, 28, 28)))

# %% [markdown]
# ### Greedy layer-wise training

# %%
def train_dbn(dbn, layer_idx, dataset, batch_size):
    dataset = propagate_up(dbn, layer_idx, dataset)
    
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(dbn[layer_idx], batch)
        if batch_idx % round(batches_limit / 50) == 0: print("#", end="")

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

LEARNING_RATE = 0.1
MOMENTUM = 0.5

DBN_HIDDEN_LAYER_SIZE = 200
dbn = [
    Rbm(VISIBLE_LAYER_SIZE, DBN_HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM),
    Rbm(DBN_HIDDEN_LAYER_SIZE, DBN_HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM),
    Rbm(DBN_HIDDEN_LAYER_SIZE, DBN_HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM)
]

for layer_idx in range(len(dbn)):
    print("\nLearning layer {}".format(layer_idx))

    for epoch in range(EPOCHS_COUNT):
        print("Epoch {}:".format(epoch),  end="\t")

        if epoch == 5:
            dbn[layer_idx].momentum = 0.8
        
        start_time = time.time()
        train_dbn(dbn, layer_idx, dataset, BATCH_SIZE)
        elapsed = time.time() - start_time
        
        error = dbn_reconstuction_error(dbn, layer_idx, monitoring_set)
        print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))
    
print("Training finished!")
# Out:
# Learning layer 0
# Epoch 0:	#####################################################	elapsed: 1.44s, reconstruction error: 24.53
# Epoch 1:	#####################################################	elapsed: 1.30s, reconstruction error: 19.26
# Epoch 2:	#####################################################	elapsed: 1.34s, reconstruction error: 16.73
# Epoch 3:	#####################################################	elapsed: 1.35s, reconstruction error: 15.13
# Epoch 4:	#####################################################	elapsed: 1.37s, reconstruction error: 14.08
# Epoch 5:	#####################################################	elapsed: 1.66s, reconstruction error: 12.96
# Epoch 6:	#####################################################	elapsed: 1.82s, reconstruction error: 11.98
# Epoch 7:	#####################################################	elapsed: 2.12s, reconstruction error: 11.34
# Epoch 8:	#####################################################	elapsed: 1.69s, reconstruction error: 10.78
# Epoch 9:	#####################################################	elapsed: 1.62s, reconstruction error: 10.46
# Epoch 10:	#####################################################	elapsed: 1.39s, reconstruction error: 10.37
# Epoch 11:	#####################################################	elapsed: 1.35s, reconstruction error: 10.21
# Epoch 12:	#####################################################	elapsed: 1.33s, reconstruction error: 10.12
# Epoch 13:	#####################################################	elapsed: 1.40s, reconstruction error: 9.75
# Epoch 14:	#####################################################	elapsed: 1.44s, reconstruction error: 9.70
# Epoch 15:	#####################################################	elapsed: 1.42s, reconstruction error: 9.41
# Epoch 16:	#####################################################	elapsed: 1.44s, reconstruction error: 9.26
# Epoch 17:	#####################################################	elapsed: 1.62s, reconstruction error: 9.44
# Epoch 18:	#####################################################	elapsed: 1.35s, reconstruction error: 9.22
# Epoch 19:	#####################################################	elapsed: 1.62s, reconstruction error: 9.10
# Epoch 20:	#####################################################	elapsed: 1.61s, reconstruction error: 9.08
# Epoch 21:	#####################################################	elapsed: 1.50s, reconstruction error: 9.08
# Epoch 22:	#####################################################	elapsed: 1.59s, reconstruction error: 9.03
# Epoch 23:	#####################################################	elapsed: 1.40s, reconstruction error: 9.04
# Epoch 24:	#####################################################	elapsed: 1.43s, reconstruction error: 8.78
# Epoch 25:	#####################################################	elapsed: 1.33s, reconstruction error: 8.89
# Epoch 26:	#####################################################	elapsed: 1.35s, reconstruction error: 8.71
# Epoch 27:	#####################################################	elapsed: 1.69s, reconstruction error: 8.75
# Epoch 28:	#####################################################	elapsed: 2.11s, reconstruction error: 8.73
# Epoch 29:	#####################################################	elapsed: 2.18s, reconstruction error: 8.75
# Epoch 30:	#####################################################	elapsed: 1.41s, reconstruction error: 8.62
# Epoch 31:	#####################################################	elapsed: 1.96s, reconstruction error: 8.68
# Epoch 32:	#####################################################	elapsed: 1.36s, reconstruction error: 8.66
# Epoch 33:	#####################################################	elapsed: 1.43s, reconstruction error: 8.81
# Epoch 34:	#####################################################	elapsed: 2.02s, reconstruction error: 8.49
# Epoch 35:	#####################################################	elapsed: 1.81s, reconstruction error: 8.63
# Epoch 36:	#####################################################	elapsed: 2.35s, reconstruction error: 8.65
# Epoch 37:	#####################################################	elapsed: 2.21s, reconstruction error: 8.56
# Epoch 38:	#####################################################	elapsed: 1.48s, reconstruction error: 8.46
# Epoch 39:	#####################################################	elapsed: 1.52s, reconstruction error: 8.53
# Epoch 40:	#####################################################	elapsed: 1.44s, reconstruction error: 8.45
# Epoch 41:	#####################################################	elapsed: 1.43s, reconstruction error: 8.39
# Epoch 42:	#####################################################	elapsed: 1.95s, reconstruction error: 8.57
# Epoch 43:	#####################################################	elapsed: 1.41s, reconstruction error: 8.25
# Epoch 44:	#####################################################	elapsed: 1.48s, reconstruction error: 8.55
# Epoch 45:	#####################################################	elapsed: 1.50s, reconstruction error: 8.44
# Epoch 46:	#####################################################	elapsed: 1.49s, reconstruction error: 8.35
# Epoch 47:	#####################################################	elapsed: 1.46s, reconstruction error: 8.40
# Epoch 48:	#####################################################	elapsed: 2.40s, reconstruction error: 8.09
# Epoch 49:	#####################################################	elapsed: 2.28s, reconstruction error: 8.37
#
# Learning layer 1
# Epoch 0:	#####################################################	elapsed: 1.28s, reconstruction error: 14.27
# Epoch 1:	#####################################################	elapsed: 1.47s, reconstruction error: 10.95
# Epoch 2:	#####################################################	elapsed: 1.28s, reconstruction error: 9.08
# Epoch 3:	#####################################################	elapsed: 1.72s, reconstruction error: 8.22
# Epoch 4:	#####################################################	elapsed: 1.91s, reconstruction error: 7.55
# Epoch 5:	#####################################################	elapsed: 2.17s, reconstruction error: 6.82
# Epoch 6:	#####################################################	elapsed: 1.89s, reconstruction error: 6.18
# Epoch 7:	#####################################################	elapsed: 1.62s, reconstruction error: 5.88
# Epoch 8:	#####################################################	elapsed: 1.82s, reconstruction error: 5.53
# Epoch 9:	#####################################################	elapsed: 1.71s, reconstruction error: 5.38
# Epoch 10:	#####################################################	elapsed: 1.56s, reconstruction error: 5.27
# Epoch 11:	#####################################################	elapsed: 1.17s, reconstruction error: 5.12
# Epoch 12:	#####################################################	elapsed: 1.24s, reconstruction error: 5.03
# Epoch 13:	#####################################################	elapsed: 1.34s, reconstruction error: 4.91
# Epoch 14:	#####################################################	elapsed: 1.15s, reconstruction error: 4.83
# Epoch 15:	#####################################################	elapsed: 1.30s, reconstruction error: 4.69
# Epoch 16:	#####################################################	elapsed: 1.24s, reconstruction error: 4.74
# Epoch 17:	#####################################################	elapsed: 1.05s, reconstruction error: 4.59
# Epoch 18:	#####################################################	elapsed: 1.03s, reconstruction error: 4.60
# Epoch 19:	#####################################################	elapsed: 1.21s, reconstruction error: 4.51
# Epoch 20:	#####################################################	elapsed: 1.23s, reconstruction error: 4.59
# Epoch 21:	#####################################################	elapsed: 1.12s, reconstruction error: 4.42
# Epoch 22:	#####################################################	elapsed: 1.10s, reconstruction error: 4.37
# Epoch 23:	#####################################################	elapsed: 1.22s, reconstruction error: 4.40
# Epoch 24:	#####################################################	elapsed: 1.36s, reconstruction error: 4.40
# Epoch 25:	#####################################################	elapsed: 1.17s, reconstruction error: 4.33
# Epoch 26:	#####################################################	elapsed: 1.27s, reconstruction error: 4.36
# Epoch 27:	#####################################################	elapsed: 1.12s, reconstruction error: 4.35
# Epoch 28:	#####################################################	elapsed: 1.17s, reconstruction error: 4.28
# Epoch 29:	#####################################################	elapsed: 1.03s, reconstruction error: 4.14
# Epoch 30:	#####################################################	elapsed: 1.03s, reconstruction error: 4.35
# Epoch 31:	#####################################################	elapsed: 1.02s, reconstruction error: 4.17
# Epoch 32:	#####################################################	elapsed: 1.04s, reconstruction error: 4.25
# Epoch 33:	#####################################################	elapsed: 1.17s, reconstruction error: 4.18
# Epoch 34:	#####################################################	elapsed: 1.00s, reconstruction error: 4.20
# Epoch 35:	#####################################################	elapsed: 1.09s, reconstruction error: 4.16
# Epoch 36:	#####################################################	elapsed: 1.07s, reconstruction error: 4.04
# Epoch 37:	#####################################################	elapsed: 0.97s, reconstruction error: 4.16
# Epoch 38:	#####################################################	elapsed: 0.92s, reconstruction error: 4.17
# Epoch 39:	#####################################################	elapsed: 1.00s, reconstruction error: 4.15
# Epoch 40:	#####################################################	elapsed: 0.97s, reconstruction error: 4.24
# Epoch 41:	#####################################################	elapsed: 1.03s, reconstruction error: 4.12
# Epoch 42:	#####################################################	elapsed: 1.05s, reconstruction error: 4.09
# Epoch 43:	#####################################################	elapsed: 0.95s, reconstruction error: 4.08
# Epoch 44:	#####################################################	elapsed: 1.08s, reconstruction error: 4.03
# Epoch 45:	#####################################################	elapsed: 0.96s, reconstruction error: 4.09
# Epoch 46:	#####################################################	elapsed: 1.18s, reconstruction error: 4.05
# Epoch 47:	#####################################################	elapsed: 0.95s, reconstruction error: 3.99
# Epoch 48:	#####################################################	elapsed: 0.96s, reconstruction error: 4.04
# Epoch 49:	#####################################################	elapsed: 0.99s, reconstruction error: 4.11
#
# Learning layer 2
# Epoch 0:	#####################################################	elapsed: 1.06s, reconstruction error: 10.08
# Epoch 1:	#####################################################	elapsed: 1.33s, reconstruction error: 7.51
# Epoch 2:	#####################################################	elapsed: 1.17s, reconstruction error: 6.22
# Epoch 3:	#####################################################	elapsed: 1.14s, reconstruction error: 5.54
# Epoch 4:	#####################################################	elapsed: 1.06s, reconstruction error: 5.00
# Epoch 5:	#####################################################	elapsed: 1.21s, reconstruction error: 4.46
# Epoch 6:	#####################################################	elapsed: 1.08s, reconstruction error: 4.22
# Epoch 7:	#####################################################	elapsed: 0.95s, reconstruction error: 3.90
# Epoch 8:	#####################################################	elapsed: 1.01s, reconstruction error: 3.82
# Epoch 9:	#####################################################	elapsed: 1.14s, reconstruction error: 3.64
# Epoch 10:	#####################################################	elapsed: 1.13s, reconstruction error: 3.48
# Epoch 11:	#####################################################	elapsed: 1.33s, reconstruction error: 3.40
# Epoch 12:	#####################################################	elapsed: 1.36s, reconstruction error: 3.40
# Epoch 13:	#####################################################	elapsed: 1.39s, reconstruction error: 3.33
# Epoch 14:	#####################################################	elapsed: 1.19s, reconstruction error: 3.51
# Epoch 15:	#####################################################	elapsed: 1.08s, reconstruction error: 3.25
# Epoch 16:	#####################################################	elapsed: 1.18s, reconstruction error: 3.27
# Epoch 17:	#####################################################	elapsed: 1.16s, reconstruction error: 3.29
# Epoch 18:	#####################################################	elapsed: 1.23s, reconstruction error: 3.23
# Epoch 19:	#####################################################	elapsed: 1.27s, reconstruction error: 3.12
# Epoch 20:	#####################################################	elapsed: 1.25s, reconstruction error: 3.26
# Epoch 21:	#####################################################	elapsed: 1.37s, reconstruction error: 3.17
# Epoch 22:	#####################################################	elapsed: 1.11s, reconstruction error: 3.10
# Epoch 23:	#####################################################	elapsed: 1.17s, reconstruction error: 3.11
# Epoch 24:	#####################################################	elapsed: 1.15s, reconstruction error: 3.11
# Epoch 25:	#####################################################	elapsed: 1.24s, reconstruction error: 3.04
# Epoch 26:	#####################################################	elapsed: 1.32s, reconstruction error: 2.93
# Epoch 27:	#####################################################	elapsed: 1.59s, reconstruction error: 3.07
# Epoch 28:	#####################################################	elapsed: 1.44s, reconstruction error: 3.09
# Epoch 29:	#####################################################	elapsed: 1.56s, reconstruction error: 3.10
# Epoch 30:	#####################################################	elapsed: 1.14s, reconstruction error: 3.07
# Epoch 31:	#####################################################	elapsed: 1.19s, reconstruction error: 2.94
# Epoch 32:	#####################################################	elapsed: 1.11s, reconstruction error: 2.97
# Epoch 33:	#####################################################	elapsed: 1.20s, reconstruction error: 3.00
# Epoch 34:	#####################################################	elapsed: 1.13s, reconstruction error: 3.09
# Epoch 35:	#####################################################	elapsed: 1.33s, reconstruction error: 3.03
# Epoch 36:	#####################################################	elapsed: 1.19s, reconstruction error: 2.89
# Epoch 37:	#####################################################	elapsed: 1.23s, reconstruction error: 2.96
# Epoch 38:	#####################################################	elapsed: 1.18s, reconstruction error: 2.96
# Epoch 39:	#####################################################	elapsed: 1.26s, reconstruction error: 2.91
# Epoch 40:	#####################################################	elapsed: 1.30s, reconstruction error: 2.94
# Epoch 41:	#####################################################	elapsed: 1.15s, reconstruction error: 3.07
# Epoch 42:	#####################################################	elapsed: 1.17s, reconstruction error: 2.86
# Epoch 43:	#####################################################	elapsed: 1.28s, reconstruction error: 2.91
# Epoch 44:	#####################################################	elapsed: 1.14s, reconstruction error: 3.07
# Epoch 45:	#####################################################	elapsed: 2.18s, reconstruction error: 2.91
# Epoch 46:	#####################################################	elapsed: 1.27s, reconstruction error: 2.89
# Epoch 47:	#####################################################	elapsed: 1.27s, reconstruction error: 2.81
# Epoch 48:	#####################################################	elapsed: 1.21s, reconstruction error: 2.80
# Epoch 49:	#####################################################	elapsed: 1.24s, reconstruction error: 2.89
# Training finished!

# %%
draw_layer_samples(dbn, 0, monitoring_set[:8*16])

# %%
draw_layer_samples(dbn, 1, monitoring_set[:8*16])

# %%
draw_layer_samples(dbn, 2, monitoring_set[:8*16])
